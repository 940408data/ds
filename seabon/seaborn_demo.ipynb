# %%
import numpy as np
import pandas as pd

# %% [markdown]
# set_style( )是用来设置主题的，Seaborn有五个预设好的主题： darkgrid , whitegrid , dark , white ,和 ticks  默认： darkgrid

# %%
import matplotlib.pyplot as plt  
import seaborn as sns  
sns.set_style("ticks")  
plt.plot(np.arange(10))  
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set(style="darkgrid", palette="muted", color_codes=True)     #set( )设置主题，调色板更常用
mpl.rcParams['font.sans-serif'] = ['SimHei']
mpl.rcParams['axes.unicode_minus'] = False
plt.title("汉语")
plt.xlabel("横坐标")
plt.plot(np.arange(10))  
plt.show()

# %% [markdown]
# 2  distplot( )  kdeplot( )
# distplot( )为hist加强版，kdeplot( )为密度曲线图

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df_iris = pd.read_csv(r'C:\Users\lenovo\Desktop\Myjupyter\seaborn-data-master\seaborn-data-master\iris.csv')
fig, axes = plt.subplots(1,2)
sns.distplot(df_iris['petal_length'], ax = axes[0], kde = True, rug = True)        # kde 密度曲线  rug 边际毛毯
sns.kdeplot(df_iris['petal_length'], ax = axes[1], shade=True)                     # shade  阴影                       
plt.show()
# Out:
# D:\developsoft\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
import numpy as np  
import seaborn as sns  
import matplotlib.pyplot as plt  
sns.set( palette="muted", color_codes=True)  
rs = np.random.RandomState(10)  
d = rs.normal(size=100)  
f, axes = plt.subplots(2, 2, figsize=(7, 7), sharex=True)  
sns.distplot(d, kde=False, color="b", ax=axes[0, 0])  
sns.distplot(d, hist=False, rug=True, color="r", ax=axes[0, 1])  
sns.distplot(d, hist=False, color="g", kde_kws={"shade": True}, ax=axes[1, 0])  
sns.distplot(d, color="m", ax=axes[1, 1])  
plt.show()
# Out:
# D:\developsoft\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# D:\developsoft\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ## 3  箱型图 boxplot( )

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df_iris = pd.read_csv(r'C:\Users\lenovo\Desktop\Myjupyter\seaborn-data-master\seaborn-data-master\iris.csv')
sns.boxplot(x = df_iris['species'],y = df_iris['sepal_width'])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tips = pd.read_csv(r'C:\Users\lenovo\Desktop\Myjupyter\seaborn-data-master\seaborn-data-master\tips.csv')
sns.set(style="ticks")                                     #设置主题
sns.boxplot(x="day", y="total_bill", hue="sex", data=tips, palette="PRGn")   #palette 调色板
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tips = pd.read_csv(r'C:\Users\lenovo\Desktop\Myjupyter\seaborn-data-master\seaborn-data-master\tips.csv')
sns.set(style="ticks")                                     #设置主题
sns.boxplot(x="day", y="total_bill", hue="sex", data=tips, palette="PRGn")   #palette 调色板
plt.show()

# %% [markdown]
# ## 4  联合分布jointplot( )

# %%
   #右上角显示相关系数
sns.jointplot("total_bill", "tip", tips)
plt.show()
# Out:
# D:\developsoft\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# D:\developsoft\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot("total_bill", "tip", tips, kind='reg')     
plt.show()
# Out:
# D:\developsoft\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# D:\developsoft\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ## 5  热点图heatmap( )

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv(r"C:\Users\lenovo\Desktop\Myjupyter\seaborn-data-master\seaborn-data-master\car_crashes.csv")
data = data.corr()
sns.heatmap(data)
plt.show()

# %% [markdown]
# ## 6  pairplot( )

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv(r"C:\Users\lenovo\Desktop\Myjupyter\seaborn-data-master\seaborn-data-master\iris.csv")
sns.set()                        #使用默认配色
sns.pairplot(data,hue="species")   #hue 选择分类列
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
iris = pd.read_csv(r"C:\Users\lenovo\Desktop\Myjupyter\seaborn-data-master\seaborn-data-master\iris.csv")
sns.pairplot(iris, vars=["sepal_width", "sepal_length"],hue="species",palette="husl")  
plt.show()

# %% [markdown]
# ## 7  FacetGrid( )

# %%
import seaborn as sns
import matplotlib.pyplot as plt
tips = pd.read_csv(r"C:\Users\lenovo\Desktop\Myjupyter\seaborn-data-master\seaborn-data-master\tips.csv")
g = sns.FacetGrid(tips, col="time",  row="smoker")
g = g.map(plt.hist, "total_bill",  color="r")
plt.show()
